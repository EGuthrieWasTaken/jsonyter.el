# %% [markdown]
# A fixture with one stored plot: a flat-filled rectangle, no gradient
# or gridlines anywhere in it. Slicing it and finding any pixel that
# is not its one fill colour is exactly what a line-spacing or
# rounding regression looks like -- see
# jsonyter/notebook-sliced-image-has-no-background-bands.

# %%
solid_plot()
