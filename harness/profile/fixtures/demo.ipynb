# %% [markdown]
# # Harness notebook
#
# A fixture with stored outputs of every kind the renderer handles.

# %%
print(greeting)
# Out:
# hello from a stored output

# %%
6 * 7
# Out:
# 42

# %%
plot_something()

# %%
x = 1

# %%
raise ValueError("boom")
